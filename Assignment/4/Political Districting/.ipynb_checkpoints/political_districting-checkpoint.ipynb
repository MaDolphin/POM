# %%
# Import the libraries
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import networkx as nx
import numpy as np
import math
import sklearn
from gurobipy import *

# Enable high resolution plots
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %% [markdown]
# Haikun Huang, 391180
#
# Ruixiang Wang, 400655

# %% [markdown]
# Read the provided data via `pandas/geopandas`.
# Remove duplicates (by column 'plz') from `zuordnung_plz_ort.csv`. Make sure that all data frames contain the same number of rows.
# Append the state names to both the 'shape' and 'centroid' data frames.
# Reference: [read_file](https://geopandas.org/reference/geopandas.read_file.html), [read_csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html), [drop_duplicates](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html), [merge](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge.html)

# %%
df_plz_ort = pd.read_csv('zuordnung_plz_ort.csv')
df_plz_ort = df_plz_ort.drop_duplicates(subset=['plz'])

df_shape = gpd.read_file('plz-5stellig.shp')
df_shape['plz'] = df_shape['plz'].astype(int)

df_centroid = gpd.read_file('plz-5stellig-centroid.shp')
df_centroid['plz'] = df_centroid['plz'].astype(int)

assert len(df_plz_ort) == len(df_shape) == len(df_centroid)

df_shape = df_shape.merge(df_plz_ort[['plz', 'bundesland']], on='plz', how='left')
df_centroid = df_centroid.merge(df_plz_ort[['plz', 'bundesland']], on='plz', how='left')

# df_shape

# %% [markdown]
# Create a contiguity graph $G$ as described on tutOR.

# %%
G = nx.Graph()

#add nodes
idx_list = []
for idx, row in df_shape.iterrows():
    if row['bundesland'] == 'Saarland':
        plz = int(row['plz'])
        num_person = int(row['einwohner'])
        G.add_node(plz, population=num_person)
        idx_list.append(idx)

# assert len(df_shape[df_shape['bundesland'] == 'Saarland']) == len(idx_list)

#add edges
edges = []
edge_tuples = []
for i in range(len(idx_list)):
    for j in range(i+1, len(idx_list)):
        idx1 = idx_list[i]
        idx2 = idx_list[j]
        if df_shape['geometry'][idx1].touches(df_shape['geometry'][idx2]):
            edges.append((int(df_shape['plz'][idx1]), int(df_shape['plz'][idx2])))
            # checking item in edge_tuples
            if (idx1, idx2) not in edge_tuples and (idx2, idx1) not in edge_tuples:
                edge_tuples.append((idx1, idx2))

G.add_edges_from(edges)

nx.draw(G)

# G.nodes(data=True)

# %% [markdown]
# Plot the map of Saarland. The following details need to be present in the picture:
# * the borders of each postcode
# * the centroids of each postcode
# * the lines connecting the centroids of neighboring postcodes
#
# Reference: [Mapping Tools](https://geopandas.org/mapping.html), [pyplot](https://matplotlib.org/tutorials/introductory/pyplot.html), [touches](https://geopandas.org/reference.html#geopandas.GeoSeries.touches)

# %%
from shapely.geometry import Point, Polygon, LineString

df_shape_S = df_shape[df_shape['bundesland'] == 'Saarland']
df_centroid_S = df_centroid[df_centroid['bundesland'] == 'Saarland']

lines = []
for start, end in edge_tuples:
    p1 = df_centroid_S['geometry'][start][0]
    p2 = df_centroid_S['geometry'][end][0]
    lines.append(LineString([p1, p2]))

df_lines = gpd.GeoDataFrame(geometry=lines)

fig, ax = plt.subplots(figsize=(20,10))
ax.set_aspect('equal')

df_lines.plot(ax=ax, color='orange', linewidth=1)
df_shape_S.plot(ax=ax, color='honeydew', edgecolor='gray', linewidth=0.5)
df_centroid_S.plot(ax=ax, marker='o', color='red', markersize=20)

ax.axis('off')
plt.show()

# %% [markdown]
# Model the problem.
# Upload the model for the pricing problem and the function to create a shortest path tree to tutOR.

# %% [markdown]
# Split Saarland into 3 districts with the required district population being equal to 340000.

# %%
k = 3
req_p = 340000

# %% [markdown]
# Write a function that generates a feasible solution to begin with and return the according patterns. Visualize a feasible solution.

# %%
from sklearn.cluster import AgglomerativeClustering


def cal_sum(df_shape_S, label):
    df = df_shape_S[df_shape_S['init_label']==label]
    return sum(df['einwohner'])

def cluster(df_centroid_S, k, req_p, edge_tuples, df_shape_S):
    X = []
    m = len(df_centroid_S)

    for idx, row in df_centroid_S.iterrows():
        a = row['geometry'][0].x
        b = row['geometry'][0].y
        X.append([a,b])
    X = np.array(X)

    cls = AgglomerativeClustering(n_clusters = k)
    predicted_labels = cls.fit_predict(X)
    

    df_shape_S_label = df_shape_S.copy(deep=True)
    df_shape_S_label['init_label'] = predicted_labels

    # manipulate the result of clustering to make it statisities population restrict
    flag = False
    for idx2, row2 in df_shape_S_label[df_shape_S_label['init_label']==2].iterrows():
        for idx0,row0 in df_shape_S_label[df_shape_S_label['init_label']==0].iterrows():
            if row2['geometry'].touches(row0['geometry']):
                df_shape_S_label.loc[idx0, 'init_label'] = 2
                if cal_sum(df_shape_S_label, 0) < req_p:
                    flag = True
                    break
        if flag:
            break
                
    flag = False
    for idx2, row2 in df_shape_S_label[df_shape_S_label['init_label']==2].iterrows():
        for idx1, row1 in df_shape_S_label[df_shape_S_label['init_label']==1].iterrows():
            if row2['geometry'].touches(row1['geometry']):
                df_shape_S_label.loc[idx1,'init_label'] = 2
                if cal_sum(df_shape_S_label, 2) > req_p:
                    flag = True
                    break
        if flag:
            break

    flag = False
    for idx2, row2 in df_shape_S_label[df_shape_S_label['init_label']==2].iterrows():
        for idx1, row1 in df_shape_S_label[df_shape_S_label['init_label']==1].iterrows():
            if row2['geometry'].touches(row1['geometry']):
                df_shape_S_label.loc[idx1,'init_label'] = 2
                if cal_sum(df_shape_S_label, 2) > req_p:
                    flag = True
                    break
        if flag:
            break
    
    return df_shape_S_label

#edit df_centroid_S dataframe
df_shape_S_label = cluster(df_centroid_S, k, req_p, edge_tuples, df_shape_S)

#init 
#pattern is only for one district
def initialization(df_shape_S):
    patterns = []
    for i in range(k):
        patterns_item = {}
        for idx, row in df_shape_S.iterrows():
            if row['init_label'] == i:
                patterns_item[row['plz']] = 1
            else:
                patterns_item[row['plz']] = 0
        patterns.append(patterns_item)

    return patterns

patterns = initialization(df_shape_S_label)

# for i in range(k):
#     print(i,patterns[i])


df_label_0 = df_shape_S_label[df_shape_S_label['init_label']==0]
df_label_1 = df_shape_S_label[df_shape_S_label['init_label']==1]
df_label_2 = df_shape_S_label[df_shape_S_label['init_label']==2]

print(sum(df_label_0['einwohner']))
print(sum(df_label_1['einwohner']))
print(sum(df_label_2['einwohner']))

#visulization
ig, ax = plt.subplots(figsize=(20,10))
ax.set_aspect('equal')
df_label_0.plot(edgecolor='0.5',facecolor="#0C3161",ax=ax)
df_label_1.plot(edgecolor='0.5',facecolor="#F4F6F8",ax=ax)
df_label_2.plot(edgecolor='0.5',facecolor="#670020",ax=ax)
ax.axis('off')
# Out:
# 343978
# 299501
# 356967
# (6.3053959850000005, 7.455965514999999, 49.08662667499999, 49.665662825000005)

# %% [markdown]
# Write a function to construct the shortest path tree. Ignore this in the beginning and start implementing the restricted master problem and the pricing problem(s) first. Create the function, when you need it

# %%
# takes a graph G and a root node as input and returns a shortest path tree
def construct_spt(G, root):

    queue=[]
    queue.append(root)
    seen=[]
    seen.append(root)
    parent={root:None}

    while queue:
        vertex = queue.pop(0)
        nodes = [n for n in G.neighbors(vertex)]
        for w in nodes:
            if w not in seen:
                queue.append(w)
                seen.append(w)
                parent[w]=vertex
    
    spt = nx.create_empty_copy(G, with_data=True)

    for node in G.nodes():
        if node != root:
            shortest_path_list = []
            while node:
                shortest_path_list.append(node)
                node = parent[node]
            
            # reverse shortest_path_list
            # init list [terminal,c,b,a,root]
            # reversed list [root,a,b,c,terminal]
            reversed_shortest_path_list = list(reversed(shortest_path_list))

            # add edges
            for i in range(len(reversed_shortest_path_list)-1):
                spt.add_node(reversed_shortest_path_list[i], distance=i)
                spt.add_edge(reversed_shortest_path_list[i], reversed_shortest_path_list[i+1])
            spt.add_node(reversed_shortest_path_list[-1], distance=len(reversed_shortest_path_list)-1)

    return spt

# %% [markdown]
# Write a function that contains the pricing problem(s) and that returns the best patterns. Ignore this in the beginning and start implementing the restricted master problem first. Upload the pricing problem and the construct_spt(G, root) function in one file to tutOR

# %%
# the pi variables have to be indexed with the municipality ZIP-Codes, this is necessary for tutOR
# pi is a dict containing the dual variable for each constraint. The indices have to be the municipality ZIP-codes. There is one additional dual variable (which one?), it should have index 0
def solve_pricing_problem(G, req_p, pi: dict, u):
    
    # shortest-path-tree
    spt = construct_spt(G, u)

    plz_list = [m for m, _ in spt.nodes(data=True)]

    # build pricing problem
    pp = Model("political districting pricing problem")

    y={}
    for m in plz_list:
        y[m] = pp.addVar(name="y_%s" % (m), vtype=GRB.BINARY)


    # populations constrains req_p * 0.85 <= X <= req_p * 1.15
    pp.addConstr(quicksum(y[m] * spt.nodes[m]['population'] for m in plz_list) >= req_p * (1 - 0.15))
    pp.addConstr(quicksum(y[m] * spt.nodes[m]['population'] for m in plz_list) <= req_p * (1 + 0.15))

    # contiguity constrains using shortest-path-tree y0+..+ym >= ym * m
    for m in plz_list:
        path_list = nx.shortest_path(spt, source = m, target = u)
        pp.addConstr(quicksum(y[visit] for visit in path_list) >= y[m] * len(path_list))

    # solving Abs_value
    populations_deviation = pp.addVar(name="populations_deviation", vtype=GRB.INTEGER)
    pp.addConstr(populations_deviation >= quicksum(y[m] * spt.nodes[m]['population'] for m in plz_list) - req_p)
    pp.addConstr(populations_deviation >= req_p - quicksum(y[m] * spt.nodes[m]['population'] for m in plz_list))

    # pricing problem's objective
    pp.setObjective(
        quicksum(y[m] * spt.nodes[m]['distance'] for m in plz_list) + 
        populations_deviation - 
        quicksum(y[m] * pi[m] for m in plz_list) -
        pi[0], 
        GRB.MINIMIZE
    )

    # gurobi should be silent
    pp.params.outputFlag = 0

    pp.update()
    pp.optimize()
    
    return pp

# %%
def solve(G, k, req_p, patterns):

    first_pattern = None

    patterns_populations_deviation = {}

    plz_list = [m for m, _ in G.nodes(data=True)]

    # build the initial restricted master problem (RMP)
    rmp = Model("political districting RMP")

    lambdas={}
    for p in range(len(patterns)):
        lambdas[p] = rmp.addVar(name=f'lambdas_{p}', vtype = GRB.CONTINUOUS)

    demand={}
    for m in plz_list:
        demand[m] = rmp.addConstr(quicksum(patterns[p][m] * lambdas[p] 
                                    for p in range(len(patterns))) == 1, 
                                    name = "demand_%s" % (p))

    req_k = rmp.addConstr(quicksum(lambdas[p] for p in range(len(patterns))) == 3)

    for p in range(len(patterns)):
        rmp.addConstr(lambdas[p] <= 1)

    for p in range(len(patterns)):
        populations_count = 0
        for m in plz_list:
            if patterns[p][m] == 1:
                populations_count = populations_count + int(G.nodes[m]['population'])
        patterns_populations_deviation[p] = abs(populations_count - req_p)

    rmp.setObjective(
        quicksum(patterns_populations_deviation[p] * lambdas[p] for p in range(len(patterns))), 
        GRB.MINIMIZE
    )

    ############################################################################################
    
    # column generation loop
    for iteration in range(2):

        rmp.optimize()

        pi={}
        pi[0] = req_k.getAttr(GRB.Attr.Pi)
        for m in plz_list:
            pi[m] = demand[m].getAttr(GRB.Attr.Pi)
        print('pi_0: ',pi[0])

        mini_value = float('inf')
        mini_root = None

        for m in plz_list:
            pp = solve_pricing_problem(G, req_p, pi, m)
            if pp.objVal < mini_value:
                mini_value = pp.objVal
                mini_root = m

        pp = solve_pricing_problem(G, req_p, pi, mini_root)
        
        #####################################################################
#         y = dict()
#         for m in plz_list:
#             name = 'y_'+ str(m)
#             y[m] = pp.getVarByName(name)
            
#         mini_distance = 0
#         for m in plz_list:
#             mini_distance = mini_distance + y[m].x * G.nodes[m]['distance']
#         print('mini_distance: ', mini_distance)
        #####################################################################
        
        print('mini_value',mini_value)
        if mini_value < -.00001:

            #pattern update
            new_pattern = {}
            y = dict()
            for m in plz_list:
                name = 'y_'+ str(m)
                y[m] = pp.getVarByName(name)
                if y[m].x > 0.1: # sparsely store the pattern, only positive entries
                    new_pattern[m] = y[m].x
                else:
                    new_pattern[m] = 0
            patterns.append(new_pattern)

            if first_pattern == None:
                first_pattern = new_pattern

            p = len(patterns) - 1
            lambdas[p] = rmp.addVar(name=f'lambdas_{p}',
                                    column = Column(list(int(y[m].x) for m in plz_list), list(demand[m] for m in plz_list)))
                
            populations_count = 0
            for m in plz_list:
                if patterns[p][m] == 1:
                    populations_count = populations_count + int(G.nodes[m]['population'])
            patterns_populations_deviation[p] = abs(populations_count - req_p)
            
            rmp.setObjective(
                quicksum(patterns_populations_deviation[p] * lambdas[p] for p in range(len(patterns))), 
                GRB.MINIMIZE
            )

        else:
            print('optimal')
            break

    rmp.optimize()

    return rmp, patterns, first_pattern

# %%
model, patterns, first_pattern = solve(G, k, req_p, patterns)
# Out:
# Academic license - for non-commercial use only - expires 2021-08-02
# Using license file /Users/hhk/gurobi.lic
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 3 columns and 75 nonzeros
# Model fingerprint: 0xcb6b084e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+03, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 73 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective  6.144400000e+04
# pi_0:  0.0
# mini_value -61413.0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 4 columns and 93 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -6.1443000e+34   5.700000e+31   6.144300e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  20481.0
# mini_value -40472.0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 5 columns and 109 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.0015000e+34   3.800000e+31   2.001500e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  25484.75
# mini_value -46963.5
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 6 columns and 125 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -6.6737500e+33   3.900000e+31   6.673750e+03      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  25484.75
# mini_value -43622.625
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 7 columns and 143 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.8166875e+34   1.975000e+31   1.816688e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  25484.75
# mini_value -50117.125
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 8 columns and 161 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.4663375e+34   4.612500e+31   2.466338e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  28080.894736842107
# mini_value -53269.47368421053
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 9 columns and 179 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.5217579e+34   2.410526e+31   2.521758e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  28822.58823529412
# mini_value -44188.23529411765
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 10 columns and 196 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.5391647e+34   1.547059e+31   1.539165e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  27638.615384615383
# mini_value -40466.0
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 11 columns and 215 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.2859385e+34   2.107692e+31   1.285938e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  27638.615384615383
# mini_value -41923.179487179485
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 12 columns and 233 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.4316564e+34   1.933333e+31   1.431656e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  28572.304347826088
# mini_value -40999.65217391305
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 13 columns and 252 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.2459348e+34   2.945652e+31   1.245935e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  32725.420289855072
# mini_value -48982.492753623184
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 14 columns and 270 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.6291072e+34   2.556522e+31   1.629107e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  32092.757281553397
# mini_value -48032.3786407767
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 15 columns and 288 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.5971621e+34   4.125243e+31   1.597162e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds
# Optimal objective  6.144400000e+04
# pi_0:  31460.21782178218
# mini_value -50482.03465346535
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 16 columns and 306 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.9055817e+34   3.956436e+31   1.905582e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  30803.120689655174
# mini_value -50091.668103448275
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 17 columns and 323 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.9317547e+34   2.809483e+31   1.931755e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  31639.981949458484
# mini_value -58540.67870036101
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 18 columns and 343 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.6938697e+34   4.979783e+31   2.693870e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  37381.98016997168
# mini_value -69369.76203966005
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 19 columns and 361 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.2033782e+34   2.794901e+31   3.203378e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  41934.498962655605
# mini_value -65839.10165975105
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 20 columns and 379 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.3940603e+34   2.396473e+31   2.394060e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  39874.72919605078
# mini_value -60100.610719323
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 21 columns and 397 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.0259882e+34   2.188152e+31   2.025988e+04      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  37305.32167832168
# mini_value -63878.46775446776
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 22 columns and 416 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.6613146e+34   3.285237e+31   2.661315e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  37628.12264150943
# mini_value -60686.091391509435
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 23 columns and 435 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.3095969e+34   2.527679e+31   2.309597e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds
# Optimal objective  6.144400000e+04
# pi_0:  38564.7093776401
# mini_value -54638.3618698958
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 24 columns and 452 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.6105652e+34   2.907901e+31   1.610565e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  35297.31561882568
# mini_value -57905.41425604135
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 25 columns and 470 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.2641099e+34   3.779518e+31   2.264110e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  41871.37988640162
# mini_value -229312.69388573343
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 26 columns and 491 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.8749031e+35   1.427225e+32   1.874903e+05      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  36258.90707513748
# mini_value -60991.591963291605
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 27 columns and 512 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.4796685e+34   4.436967e+31   2.479668e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  39733.0507881682
# mini_value -61462.39598250844
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 28 columns and 535 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.1773345e+34   3.199007e+31   2.177335e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  38421.56718940359
# mini_value -56845.58373256144
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 29 columns and 555 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.8471017e+34   3.180374e+31   1.847102e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  41064.10483162276
# mini_value -76916.4952247517
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 30 columns and 572 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.5906390e+34   5.463124e+31   3.590639e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  37087.31816462755
# mini_value -51209.44295734812
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 31 columns and 592 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.4167125e+34   2.859600e+31   1.416712e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  36854.55145955097
# mini_value -62367.93791382399
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 32 columns and 612 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.5550386e+34   4.694657e+31   2.555039e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  36940.09884304527
# mini_value -62797.4973877804
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 33 columns and 634 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.5914399e+34   4.185532e+31   2.591440e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  35664.377366060624
# mini_value -71096.10597546505
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 34 columns and 656 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.5493729e+34   7.174247e+31   3.549373e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  45020.03404710295
# mini_value -67749.71128342011
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 35 columns and 680 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.2793677e+34   3.191639e+31   2.279368e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  35130.625771573985
# mini_value -67090.29534876857
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 36 columns and 700 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.2016670e+34   4.589325e+31   3.201667e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  50590.91183284819
# mini_value -86395.5312382478
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 37 columns and 720 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.5864619e+34   4.934292e+31   3.586462e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  -87971.89411567897
# mini_value -728675.0031609822
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 38 columns and 743 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -8.1671890e+35   4.554868e+32   8.167189e+05      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds
# Optimal objective  6.144400000e+04
# pi_0:  33129.12315311385
# mini_value -66599.15017238233
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 39 columns and 762 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.3529027e+34   3.936619e+31   3.352903e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  28801.47618318281
# mini_value -77353.19797398915
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 40 columns and 783 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -4.8609722e+34   4.847774e+31   4.860972e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  21365.610587866046
# mini_value -94989.98619064645
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 41 columns and 806 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.3690376e+34   7.236588e+31   7.369038e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  35291.60141359245
# mini_value -124005.28926289527
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 42 columns and 826 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -8.8756688e+34   2.245308e+32   8.875669e+04      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  32539.160529816363
# mini_value -65447.59704325898
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 43 columns and 847 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.2972437e+34   4.625541e+31   3.297244e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  -84071.07406614485
# mini_value -481738.56560112815
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 44 columns and 867 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.6585664e+35   3.027817e+32   5.658566e+05      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  24895.589613315315
# mini_value -56426.922638342236
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 45 columns and 889 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.1602333e+34   2.351615e+31   3.160233e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  20899.94334554537
# mini_value -105576.41269299194
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 46 columns and 912 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -8.4738469e+34   5.132285e+31   8.473847e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  29963.08070016001
# mini_value -185306.23871358085
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 47 columns and 931 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.5539716e+35   6.705131e+31   1.553972e+05      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  30186.86164488732
# mini_value -84469.15527877305
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 48 columns and 953 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.4356294e+34   3.964221e+31   5.435629e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  19102.044743946484
# mini_value -98417.773373131
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 49 columns and 975 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.9372729e+34   5.021994e+31   7.937273e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  28250.87706007345
# mini_value -109180.40176255995
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 50 columns and 1001 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -8.1006525e+34   5.351744e+31   8.100652e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  36984.986929041246
# mini_value -139227.5393760759
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 51 columns and 1022 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.0229555e+35   4.234032e+31   1.022956e+05      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  65622.29187636991
# mini_value -266061.44418519695
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 52 columns and 1042 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.0047815e+35   8.571034e+31   2.004782e+05      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  32729.789833490384
# mini_value -55913.82068677961
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 53 columns and 1064 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.3266031e+34   2.102857e+31   2.326603e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  36409.06621826936
# mini_value -124613.96318943483
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 54 columns and 1087 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -8.8265897e+34   5.920734e+31   8.826590e+04      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  13526.457183583592
# mini_value -281083.65456312685
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 55 columns and 1111 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.6763520e+35   2.048185e+32   2.676352e+05      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  30213.710471725055
# mini_value -95203.39960431913
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 56 columns and 1133 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -6.5043689e+34   3.262158e+31   6.504369e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  34693.37360222516
# mini_value -358309.2482575225
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 57 columns and 1156 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.2368187e+35   3.369560e+32   3.236819e+05      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  26451.640465258806
# mini_value -175116.32445536903
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 58 columns and 1177 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.4872668e+35   9.266524e+31   1.487267e+05      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  26754.17624400132
# mini_value -76070.12102812485
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 59 columns and 1198 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -4.9391945e+34   2.809274e+31   4.939194e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  18256.546268296937
# mini_value -366332.77230805653
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 60 columns and 1218 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.4813023e+35   3.812761e+32   3.481302e+05      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  33334.12658175518
# mini_value -91782.21092139152
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 61 columns and 1242 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.8523084e+34   5.964705e+31   5.852308e+04      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  35738.89659008887
# mini_value -109636.26852955173
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 62 columns and 1264 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.3969372e+34   5.636541e+31   7.396937e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  25318.859468647574
# mini_value -86707.93926118095
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 63 columns and 1287 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -6.1450080e+34   3.017927e+31   6.145008e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  117608.1121306459
# mini_value -1043283.8203506478
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 64 columns and 1312 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -9.2573871e+35   6.492385e+32   9.257387e+05      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  30349.780822954723
# mini_value -88572.30289206524
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 65 columns and 1336 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.8293522e+34   2.594605e+31   5.829352e+04      0s
#        3    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  32922.27349096921
# mini_value -122246.2083815088
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 66 columns and 1361 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -8.9406935e+34   4.194457e+31   8.940693e+04      0s
#        1    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  28625.796690314644
# mini_value -125529.81907749028
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 67 columns and 1385 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -9.6976022e+34   3.417711e+31   9.697602e+04      0s
#        3    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  23535.554489663613
# mini_value -89605.45524230406
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 68 columns and 1409 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -6.6138901e+34   3.557798e+31   6.613890e+04      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  34297.35473260627
# mini_value -65489.713365137184
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 69 columns and 1434 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.1263359e+34   2.141638e+31   3.126336e+04      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  35613.40090520481
# mini_value -107428.14270651326
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 70 columns and 1458 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.1890742e+34   4.162935e+31   7.189074e+04      0s
#        3    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  32476.166036458395
# mini_value -110650.05097614136
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 71 columns and 1481 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.8234885e+34   5.050586e+31   7.823488e+04      0s
#        2    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  34581.185367154416
# mini_value -82286.64385147509
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 72 columns and 1504 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -4.7782458e+34   2.217623e+31   4.778246e+04      0s
#        3    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  33998.96266081907
# mini_value -71189.36449695945
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 73 columns and 1527 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.7276402e+34   3.006893e+31   3.727640e+04      0s
#        3    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# ...
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.7779037e+34   3.972674e+31   2.777904e+04      0s
#       10    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  33503.4622984185
# mini_value -53500.53158522295
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 119 columns and 2639 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.0051069e+34   4.136425e+31   2.005107e+04      0s
#        5    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  33587.46451518806
# mini_value -50783.00908865835
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 120 columns and 2664 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.7265545e+34   1.620642e+31   1.726554e+04      0s
#       12    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.01 seconds
# Optimal objective  6.144400000e+04
# pi_0:  35343.59486975286
# mini_value -55442.36230807753
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 121 columns and 2689 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.0167767e+34   1.364806e+31   2.016777e+04      0s
#        7    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  35171.469491796226
# mini_value -51097.67316451656
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 122 columns and 2714 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.6012204e+34   1.726964e+31   1.601220e+04      0s
#       10    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  34051.56200544083
# mini_value -50073.72390609032
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 123 columns and 2741 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.6109162e+34   6.347808e+31   1.610916e+04      0s
#       12    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  32359.261628340075
# mini_value -46117.229693163295
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 124 columns and 2763 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.3823968e+34   1.993131e+31   1.382397e+04      0s
#       18    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 18 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  38604.742443506766
# mini_value -51974.35458934727
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 125 columns and 2788 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.3445612e+34   3.463278e+31   1.344561e+04      0s
#       14    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  35885.201286286465
# mini_value -56804.60064599824
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 126 columns and 2814 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.1001399e+34   1.960683e+31   2.100140e+04      0s
#       20    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 20 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  37184.309228338156
# mini_value -43305.43521658903
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 127 columns and 2837 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -6.1891260e+33   6.600150e+31   6.189126e+03      0s
#       11    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  38119.14750939384
# mini_value -40587.12395289752
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 128 columns and 2860 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.5359764e+33   1.802684e+31   2.535976e+03      0s
#       18    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 18 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  37661.18448088199
# mini_value -41147.08129261054
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 129 columns and 2886 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.5708968e+33   2.660426e+31   3.570897e+03      0s
#       13    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 13 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  37753.68973180054
# mini_value -40749.83734633999
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 130 columns and 2909 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.0501476e+33   1.431676e+31   3.050148e+03      0s
#       19    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 19 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  37930.83217811074
# mini_value -39149.3473318481
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 131 columns and 2933 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.2865152e+33   2.343392e+31   1.286515e+03      0s
#        8    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  6.144400000e+04
# pi_0:  37882.63257231322
# mini_value -39877.57974368363
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 132 columns and 2958 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.0849472e+33   3.299953e+31   2.084947e+03      0s
#        9    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  38029.16168207634
# mini_value -39783.1653934873
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 133 columns and 2980 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.8180037e+33   1.897127e+31   1.818004e+03      0s
#       13    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 13 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  38362.00024802216
# mini_value -40352.97611833873
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 134 columns and 3007 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.0729759e+33   7.669584e+31   2.072976e+03      0s
#        5    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  38648.479344931904
# mini_value -40750.83567634457
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 135 columns and 3030 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.1563563e+33   2.206795e+31   2.156356e+03      0s
#       11    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.01 seconds
# Optimal objective  6.144400000e+04
# pi_0:  38177.41353596047
# mini_value -39414.65757196149
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 136 columns and 3053 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.3082440e+33   2.242158e+31   1.308244e+03      0s
#        6    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  38022.64231621215
# mini_value -39407.26160329534
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 137 columns and 3077 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.4526193e+33   1.507964e+31   1.452619e+03      0s
#        7    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  37996.851130467265
# mini_value -39591.545286773086
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 138 columns and 3100 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.6526942e+33   3.224072e+31   1.652694e+03      0s
#        8    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  38156.94816442171
# mini_value -39758.66656879335
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 139 columns and 3124 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.6767184e+33   5.074680e+31   1.676718e+03      0s
#       11    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.01 seconds
# Optimal objective  6.144400000e+04
# pi_0:  38427.72363922922
# mini_value -40385.19682353826
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 140 columns and 3149 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.0284732e+33   4.072359e+31   2.028473e+03      0s
#       11    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.01 seconds
# Optimal objective  6.144400000e+04
# pi_0:  38048.37802097434
# mini_value -39192.545948891246
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 73 rows, 141 columns and 3175 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.2171679e+33   2.717499e+31   1.217168e+03      0s
#       11    6.1444000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.00 seconds
# Optimal objective  6.144400000e+04
# pi_0:  37803.97329285275

# %%
lambdas = dict()
for p in range(len(patterns)):
    name = 'lambdas_'+ str(p)
    lambdas[p] = model.getVarByName(name)
    print(p,lambdas[p])

# %% [markdown]
# Visualize the first pattern created. Plot the map of Saarland in the background and a graph which displays the pattern in the foreground

# %%
from shapely.geometry import Point, Polygon, LineString

df_centroid_S_label = df_centroid_S.copy(deep=True)

df_shape_S_label['init_label'] = first_pattern.values()
df_centroid_S_label['init_label'] = first_pattern.values()

df_temp = df_shape_S_label[df_shape_S_label['init_label'] == 1]
df_res = df_shape_S_label[df_shape_S_label['init_label'] == 0]
df_temp_centroid = df_centroid_S_label[df_centroid_S_label['init_label'] == 1]


#add nodes
idx_list_show = []
for idx, row in df_temp.iterrows():
        idx_list_show.append(idx)

#add edges
edge_tuples_show = []
for i in range(len(idx_list_show)):
    for j in range(i+1, len(idx_list_show)):
        idx1 = idx_list_show[i]
        idx2 = idx_list_show[j]
        if df_temp['geometry'][idx1].touches(df_temp['geometry'][idx2]):
            if (idx1, idx2) not in edge_tuples_show and (idx2, idx1) not in edge_tuples_show:
                edge_tuples_show.append((idx1, idx2))

lines = []
for start, end in edge_tuples_show:
    p1 = df_temp_centroid['geometry'][start][0]
    p2 = df_temp_centroid['geometry'][end][0]
    lines.append(LineString([p1, p2]))
df_lines = gpd.GeoDataFrame(geometry=lines)


ig, ax = plt.subplots(figsize=(20,10))
ax.set_aspect('equal')
df_lines.plot(ax=ax, color='orange', linewidth=1)
df_shape_S.plot(ax=ax, color='honeydew', edgecolor='gray', linewidth=0.3)
df_temp.plot(edgecolor='0.5',facecolor="#0C3161",ax=ax)
df_temp_centroid.plot(ax=ax, marker='o', color='red', markersize=20)
ax.axis('off')

# %% [markdown]
# Use the `Gurobi` solution to plot the map of Saarland with each district colored in different color.

# %%
plz_list = [m for m, _ in G.nodes(data=True)]

lambdas = dict()
for p in range(len(patterns)):
    name = 'lambdas_'+ str(p)
    lambdas[p] = model.getVarByName(name)
    
count_k = 0
for p in range(len(patterns)):
    if lambdas[p].x == 1:
        for m in G.nodes():
            if patterns[p][m] == 1:
                idx = df_shape_S_label[df_shape_S_label['plz'] == m].index
                df_shape_S_label.loc[idx, 'init_label'] = count_k
        count_k = count_k + 1

df_label = list()
for i in range(k):
    df_label.append(df_shape_S_label[df_shape_S_label['init_label'] == i])
    
#visulization
ig, ax = plt.subplots(figsize=(20,10))
ax.set_aspect('equal')
color = ['#0C3161', '#F4F6F8', '#670020']
for i in range(k):
    df_label[i].plot(edgecolor='0.5',facecolor = color[i],ax = ax)
ax.axis('off')

# %% [markdown]
# For each district:
# * check whether the population constraint was satisfied (print the district's population)
# * print the names of towns and villages assigned to it
#
# Reference: [sum](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html)

# %%
for i in range(k):
    print('District ',i)
    print('Population:',req_p * (1-0.15), '<=',sum(df_label[i]['einwohner']),'<=',req_p * (1+0.15))
    print('Count of Towns and villages:',len(df_label[i]))
    print('Towns and villages:')
    print(df_label[i]['note'].values.tolist())
    print()
